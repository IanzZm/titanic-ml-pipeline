# %%
## importando o dataset titanic
import sys
sys.path.append('..')

from src.limpeza import carregar_e_limpar

df = carregar_e_limpar()

# %%
#importanto as libs 
import seaborn as sn
import matplotlib.pyplot as plt

# %%
##histograma
sns.histplot(df['age'])
plt.show()

# %% [markdown]
# Pico artificial de idade 28/29 anos por causa da inserção feita para preencher valores vazios

# %%
sns.boxplot(x=df['fare'])
plt.show()

# %% [markdown]
# O boxplot de `fare` revelou 3 passageiros com tarifa acima de 400

# %%
df[df['fare'] > 400]
# Out:
#      survived pclass     sex   age  sibsp  parch      fare embarked  class  \
# 257         1      1  female  35.0      0      0  512.3292        C  First
# 678         1      1    male  36.0      0      1  512.3292        C  First
# 736         1      1    male  35.0      0      0  512.3292        C  First
#
#        who  adult_male embark_town  alive  alone    pais
# 257  woman       False   Cherbourg   True   True  França
# 678    man        True   Cherbourg   True  False  França
# 736    man        True   Cherbourg   True   True  França

# %%
df[df['fare'] > 400][['pclass', 'sex', 'age', 'fare', 'survived']]
# Out:
#     pclass     sex   age      fare  survived
# 257      1  female  35.0  512.3292         1
# 678      1    male  36.0  512.3292         1
# 736      1    male  35.0  512.3292         1

# %%
sns.scatterplot(data=df, x='age', y='fare', hue='survived')
plt.show()

# %%
sns.boxplot(x=df['fare'], y=df['pclass'], hue= df['survived'])
plt.show()

# %% [markdown]
# Insight 3: Tarifa x classe x sobrevivência
#
# Cruzando fare, pclass e survived num boxplot, dá pra ver que em
# TODAS as classes, quem sobreviveu pagou tarifa mais alta em média
# que quem não sobreviveu — reforça o padrão já visto na sessão 1
# (status/dinheiro influenciando taxa de sobrevivência).
